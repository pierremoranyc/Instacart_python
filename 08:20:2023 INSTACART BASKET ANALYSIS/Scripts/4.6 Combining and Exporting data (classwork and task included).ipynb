# %%
import os
import numpy as np
import pandas as pd

# %%
path = r'/Users/pierremora/Desktop/08:20:2023 INSTACART BASKET ANALYSIS'

# %%
# IMPORTING THE 2 DATAFRAMES
orders = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'orders_clean.csv'), index_col = None)
orders_prods = pd.read_csv(os.path.join(path, 'Data', 'Original Data','orders_products_prior.csv'),index_col = None)

# %%
# checking orders columns
orders.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'user_id', 'eval_set', 'number_of_orders',
#        'orders_day_of_week', 'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
orders_prods
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %%
# droping columns we do not need
orders.drop(columns = {'eval_set', 'Unnamed: 0'}, inplace = True)

# %%
# Changing types for orders data set 

orders['order_id'] =orders['order_id'].astype('int32')
orders['user_id']=orders['user_id'].astype('int8')
orders['number_of_orders']=orders['number_of_orders'].astype('int32')
orders['orders_day_of_week']=orders['orders_day_of_week'].astype('int8')
orders['order_hour_of_day']= orders['order_hour_of_day'].astype('int32')
orders['days_since_prior_order']=orders['days_since_prior_order'].astype('int64')

# %%
#checking memory usage on orders dataframe, trying to optimize ram usage before actions
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 6 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int32
#  1   user_id                 int8
#  2   number_of_orders        int32
#  3   orders_day_of_week      int8
#  4   order_hour_of_day       int32
#  5   days_since_prior_order  int64
# dtypes: int32(3), int64(1), int8(2)
# memory usage: 71.8 MB

# %%
# checking orders_prods columns
orders_prods.columns
# Out:
# Index(['order_id', 'product_id', 'add_to_cart_order', 'reordered'], dtype='object')

# %%
#checking actual memory usage
orders_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 989.8 MB

# %%
# Changing types for orders_prods data set 
orders_prods['order_id']= orders_prods['order_id'].astype('int64')
orders_prods['product_id']=orders_prods['product_id'].astype('int64')
orders_prods['add_to_cart_order']=orders_prods['add_to_cart_order'].astype('int64')
orders_prods['reordered']= orders_prods['reordered'].astype('int64')

# %%
#checking memory usage on orders_prods dataframe, trying to optimize ram usage before actions
orders_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 989.8 MB

# %%
orders.head()
# Out:
#    order_id  user_id  number_of_orders  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1                 1                   2                  8
# 1   2398795        1                 2                   3                  7
# 2    473747        1                 3                   3                 12
# 3   2254736        1                 4                   4                  7
# 4    431534        1                 5                   4                 15
#
#    days_since_prior_order
# 0                       0
# 1                      15
# 2                      21
# 3                      29
# 4                      28

# %%
orders_prods.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
orders_prods.dtypes
# Out:
# order_id             int64
# product_id           int64
# add_to_cart_order    int64
# reordered            int64
# dtype: object

# %%
df_merged_large = orders.merge(orders_prods, on = 'order_id', indicator = True)

# %%
df_merged_large
# Out:
#           order_id  user_id  number_of_orders  orders_day_of_week  \
# 0          2539329        1                 1                   2
# 1          2539329        1                 1                   2
# 2          2539329        1                 1                   2
# 3          2539329        1                 1                   2
# 4          2539329        1                 1                   2
# ...            ...      ...               ...                 ...
# 32434484   2977660     -127                13                   1
# 32434485   2977660     -127                13                   1
# 32434486   2977660     -127                13                   1
# 32434487   2977660     -127                13                   1
# 32434488   2977660     -127                13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                       0         196
# ...

# %%
#exporting data
# Export data to pkl

df_merged_large.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# # TASK 4.6

# %%
#importing both dataframes (orders_products_combined and products_clean)
orders_prods_comb = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_combined.pkl'))
products_clean = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'products_clean.csv'), index_col = None)

# %%
# checking dataframes shape
orders_prods_comb.shape
# Out:
# (32434489, 10)

# %%
orders_prods_comb.head()
# Out:
#    order_id  user_id  number_of_orders  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1                 1                   2                  8
# 1   2539329        1                 1                   2                  8
# 2   2539329        1                 1                   2                  8
# 3   2539329        1                 1                   2                  8
# 4   2539329        1                 1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                       0         196                  1          0   both
# 1                       0       14084                  2          0   both
# 2                       0       12427                  3          0   both
# 3                       0       26088                  4          0   both
# 4                       0       26405                  5          0   both

# %%
products_clean.shape
# Out:
# (49672, 6)

# %%
products_clean.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
orders_prods_comb['user_id'] = orders_prods_comb['user_id'].abs()

# %%
# Dropping column "unnamed"
orders_prods_comb = orders_prods_comb.drop(['_merge'], axis = 1)

# %% [markdown]
# # Merging products_clean dataframe into orders_prods_comb using inner join

# %%
merged_orders_products_comb = products_clean.merge(orders_prods_comb, on = 'product_id', indicator = True)

# %%
merged_orders_products_comb.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  number_of_orders  orders_day_of_week  order_hour_of_day  \
# 0   3139998      118                28                   6                 11
# 1   1977647      118                30                   6                 17
# 2    389851       59                 2                   0                 21
# 3    652770        4                 1                   3                 13
# 4   1813452        4                 3                   4                 17
#
# ...

# %% [markdown]
# # Exporting dataframe (pickle format)

# %%
# Export data to pkl

merged_orders_products_comb.to_pickle(os.path.join(path, 'Data','Prepared Data', 'merged_orders_products_name.pkl'))
